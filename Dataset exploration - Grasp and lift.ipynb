# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

from __future__ import unicode_literals

import time
from sys import getsizeof

# %%
data = np.loadtxt(open('data/train/subj1_series3_data.csv','r'), skiprows=1, usecols=[1, 2], delimiter=',')
events = np.loadtxt(open('data/train/subj1_series3_events.csv','r'), skiprows=1, usecols=[1, 2, 3, 4, 5, 6], delimiter=',')

# %%
mmax = 10000

print data.shape
plt.figure(figsize=(15, 8))
plt.plot(data[:mmax, 0], linewidth=0.5)
plt.plot(data[:mmax, 1], linewidth=0.5, color='g')
axe = plt.twinx()
axe.plot(events[:mmax,0], linewidth=2.0, color='r')
axe.plot(events[:mmax,1], linewidth=2.0, color='g')
axe.plot(events[:mmax,2], linewidth=2.0, color='y')
axe.plot(events[:mmax,3], linewidth=2.0, color='grey')
axe.plot(events[:mmax,4], linewidth=2.0, color='purple')
axe.plot(events[:mmax,5], linewidth=2.0, color='orange')
# Out:
# (217614, 2)

# %%
print events.nbytes
# Out:
# 10445472
